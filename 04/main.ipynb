# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("HousingData.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %% [markdown]
# ### Data description

# %% [markdown]
# | Abbreviation | Description                                                   |
# |--------------|---------------------------------------------------------------|
# | CRIM         | Per capita crime rate by town                                |
# | ZN           | Proportion of residential land zoned for lots over 25,000 sq.ft. |
# | INDUS        | Proportion of non-retail business acres per town              |
# | CHAS         | Charles River dummy variable (1 if tract bounds river; 0 otherwise) |
# | NOX          | Nitric oxides concentration (parts per 10 million)           |
# | RM           | Average number of rooms per dwelling                         |
# | AGE          | Proportion of owner-occupied units built prior to 1940       |
# | DIS          | Weighted distances to five Boston employment centres         |
# | RAD          | Index of accessibility to radial highways                     |
# | TAX          | Full-value property-tax rate per $10,000                      |
# | PTRATIO      | Pupil-teacher ratio by town                                   |
# | B            | 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town |
# | LSTAT        | % lower status of the population                              |
# | MEDV         | Median value of owner-occupied homes in $1000's               |

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ### Column description

# %% [markdown]
# #### CRIM

# %%
df["CRIM"].value_counts()
# Out:
# CRIM
# 14.33370    2
# 0.01501     2
# 0.00632     1
# 0.05023     1
# 0.02543     1
#            ..
# 1.34284     1
# 1.22358     1
# 2.44668     1
# 3.53501     1
# 0.04741     1
# Name: count, Length: 484, dtype: int64

# %%
sns.histplot(df, x="CRIM")
plt.show()

# %% [markdown]
# #### ZN

# %%
df["ZN"].value_counts()
# Out:
# ZN
# 0.0      360
# 20.0      20
# 80.0      14
# 22.0      10
# 12.5      10
# 25.0      10
# 45.0       6
# 40.0       6
# 30.0       5
# 90.0       5
# 95.0       4
# 60.0       4
# 33.0       4
# 21.0       4
# 55.0       3
# 70.0       3
# 75.0       3
# 52.5       3
# 35.0       2
# 82.5       2
# 28.0       2
# 85.0       2
# 17.5       1
# 100.0      1
# 34.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
sns.histplot(df, x="ZN")
plt.show()

# %% [markdown]
# #### INDUS

# %%
df["INDUS"].value_counts()
# Out:
# INDUS
# 18.10    127
# 19.58     28
# 8.14      22
# 6.20      18
# 21.89     14
#         ...
# 1.32       1
# 1.38       1
# 3.75       1
# 0.46       1
# 2.31       1
# Name: count, Length: 76, dtype: int64

# %%
sns.histplot(df, x="INDUS")
plt.show()

# %% [markdown]
# #### CHAS

# %%
df["CHAS"].value_counts()
# Out:
# CHAS
# 0.0    452
# 1.0     34
# Name: count, dtype: int64

# %%
sns.histplot(df, x="CHAS")
plt.show()

# %% [markdown]
# #### NOX

# %%
df["NOX"].value_counts()
# Out:
# NOX
# 0.538    23
# 0.713    18
# 0.437    17
# 0.871    16
# 0.624    15
#          ..
# 0.394     1
# 0.518     1
# 0.385     1
# 0.389     1
# 0.435     1
# Name: count, Length: 81, dtype: int64

# %%
sns.histplot(df, x="NOX")
plt.show()

# %% [markdown]
# #### RM

# %%
df["RM"].value_counts()
# Out:
# RM
# 5.713    3
# 6.167    3
# 6.127    3
# 6.229    3
# 6.405    3
#         ..
# 5.859    1
# 6.416    1
# 5.572    1
# 5.880    1
# 6.976    1
# Name: count, Length: 446, dtype: int64

# %%
sns.histplot(df, x="RM")
plt.show()

# %% [markdown]
# #### AGE

# %%
df["AGE"].value_counts().sort_values(ascending=False)
# Out:
# AGE
# 100.0    42
# 97.9      4
# 98.8      4
# 96.0      4
# 95.4      4
#          ..
# 56.4      1
# 49.3      1
# 58.5      1
# 8.9       1
# 89.3      1
# Name: count, Length: 348, dtype: int64

# %%
sns.histplot(df, x="AGE")
plt.show()

# %% [markdown]
# #### DIS

# %%
df["DIS"].value_counts()
# Out:
# DIS
# 3.4952    5
# 5.7209    4
# 5.2873    4
# 6.8147    4
# 5.4007    4
#          ..
# 2.4220    1
# 2.1620    1
# 2.0407    1
# 1.9709    1
# 2.5050    1
# Name: count, Length: 412, dtype: int64

# %%
sns.histplot(df, x="DIS")
plt.show()

# %% [markdown]
# #### RAD

# %%
df["RAD"].value_counts()
# Out:
# RAD
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 2      24
# 8      24
# 1      20
# 7      17
# Name: count, dtype: int64

# %%
sns.histplot(df, x="RAD")
plt.show()

# %% [markdown]
# #### TAX

# %%
df["TAX"].value_counts()
# Out:
# TAX
# 666    132
# 307     40
# 403     30
# 437     15
# 304     14
#       ...
# 285      1
# 198      1
# 256      1
# 244      1
# 313      1
# Name: count, Length: 66, dtype: int64

# %%
sns.histplot(df, x="TAX")
plt.show()

# %% [markdown]
# #### PTRATIO

# %%
df["PTRATIO"].value_counts()
# Out:
# PTRATIO
# 20.2    140
# 14.7     34
# 21.0     27
# 17.8     23
# 19.2     19
# 17.4     18
# 18.6     17
# 19.1     17
# 18.4     16
# 16.6     16
# 21.2     15
# 15.2     13
# 13.0     12
# 17.9     11
# 20.9     11
# 18.7      9
# 19.6      8
# 19.7      8
# 17.6      7
# 16.4      6
# 16.9      5
# 16.0      5
# 20.1      5
# 18.0      5
# 16.1      5
# 19.0      4
# 18.3      4
# 16.8      4
# 18.2      4
# 14.9      4
# 18.5      4
# 17.0      4
# 18.9      3
# 12.6      3
# 14.8      3
# 15.3      3
# 15.9      2
# 15.6      2
# 18.8      2
# 22.0      2
# 13.6      1
# 15.1      1
# 17.3      1
# 21.1      1
# 14.4      1
# 15.5      1
# Name: count, dtype: int64

# %%
sns.histplot(df, x="PTRATIO")
plt.show()

# %% [markdown]
# #### B

# %%
df["B"].value_counts()
# Out:
# B
# 396.90    121
# 393.74      3
# 395.24      3
# 376.14      2
# 394.72      2
#          ...
# 240.16      1
# 389.61      1
# 374.43      1
# 338.92      1
# 391.99      1
# Name: count, Length: 357, dtype: int64

# %%
sns.histplot(df, x="B")
plt.show()

# %% [markdown]
# #### LSTAT

# %%
df["LSTAT"].value_counts()
# Out:
# LSTAT
# 7.79     3
# 6.36     3
# 8.05     3
# 14.10    3
# 18.13    3
#         ..
# 3.32     1
# 1.92     1
# 1.73     1
# 6.43     1
# 7.88     1
# Name: count, Length: 438, dtype: int64

# %%
sns.histplot(df, x="LSTAT")
plt.show()

# %% [markdown]
# #### MEDV

# %%
df["MEDV"].value_counts()
# Out:
# MEDV
# 50.0    16
# 25.0     8
# 22.0     7
# 21.7     7
# 23.1     7
#         ..
# 32.9     1
# 34.6     1
# 30.3     1
# 33.3     1
# 8.1      1
# Name: count, Length: 229, dtype: int64

# %%
sns.histplot(df, x="MEDV")
plt.show()

# %% [markdown]
# ### Correlation

# %% [markdown]
# As you can see from chart, highest correlation has cols TAX and RAD

# %% [markdown]
# Another significant combinations are:
# - LSTAT - MEDV
# - RM - MEDV
# - INDUS - TAX
# - DIS - AGE
# - DIS - NOX
# - DIS - INDUS
# - AGE - NOX
# - INDUS - NOX

# %% [markdown]
# I would consider CHAS column as irelevant

# %%
f, ax = plt.subplots(figsize=(11, 9))
sns.heatmap(df.corr(), cmap="coolwarm", annot=True, linewidths=.5, square=True)
plt.show()

# %% [markdown]
# ### Summary

# %% [markdown]
# Very significant predictor for median value is LSTAT, PTRATIO and RM

# %% [markdown]
# there are many houses with age 100, which probably means, that it is the max value for the dataset. So is probably means age >= 100

# %% [markdown]
# median value mean is 22.533, while its median is is 21.2, which means it is little bit skewed to the left. More of median values are lower than average.
